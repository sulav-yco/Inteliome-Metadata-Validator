# %%
import yaml
from simple_ddl_parser.parser import Parser

# %%
from simple_ddl_parser import DDLParser
from pprint import pprint

parse_results = DDLParser("""create or replace TABLE INFRA_DB.INFRA_SCHEMA.INFRA_ASSET_DETAILS (
	ASSET_ID NUMBER(38,0) COMMENT 'Asset ID',
	ASSET_TAG VARCHAR(16777216) COMMENT 'Unique identifier for the asset',
	ASSET_NAME VARCHAR(16777216) COMMENT 'Name of the asset',
	ASSET_SERIAL VARCHAR(16777216) COMMENT 'Serial number of the asset',
	MODEL_NAME VARCHAR(16777216) COMMENT 'Name of the model associated with the asset',
	MODEL_NUMBER VARCHAR(16777216) COMMENT 'Model number of the asset',
	MANUFACTURER_NAME VARCHAR(16777216) COMMENT 'Name of the manufacturer of the asset',
	CATEGORY_NAME VARCHAR(16777216) COMMENT 'Category name of the asset',
	CATEGORY_TYPE VARCHAR(16777216) COMMENT 'Category type of the asset',
	STATUS_NAME VARCHAR(16777216) COMMENT 'Name of the asset status',
	STATUS_DEPLOYABLE NUMBER(38,0) COMMENT 'Indicates whether the asset is deployable',
	STATUS_PENDING NUMBER(38,0) COMMENT 'Indicates whether the asset is pending',
	STATUS_ARCHIVED NUMBER(38,0) COMMENT 'Indicates whether the asset is archived',
	STATUS_NOTES VARCHAR(16777216) COMMENT 'Additional notes on the asset status',
	ASSET_ASSIGNED_TO VARCHAR(16777216) COMMENT 'ID of the user to whom the asset is assigned',
	ASSET_USER_ID VARCHAR(16777216) COMMENT 'User ID associated with the asset',
	USER_EMAIL VARCHAR(16777216) COMMENT 'Email address of the assigned user',
	FULL_NAME VARCHAR(16777216) COMMENT 'Full name of the assigned user',
	USERNAME VARCHAR(16777216) COMMENT 'Username of the assigned user',
	SUPPLIER_ID VARCHAR(16777216) COMMENT 'ID of the supplier who provided the asset',
	SUPPLIER_NAME VARCHAR(16777216) COMMENT 'Name of the supplier',
	COMPANY_ID VARCHAR(16777216) COMMENT 'ID of the company owning the asset',
	COMPANY_NAME VARCHAR(16777216) COMMENT 'Name of the company',
	ASSET_PURCHASE_DATE DATE COMMENT 'Purchase date of the asset',
	ASSET_EOL_DATE DATE COMMENT 'End of life date for the asset',
	ASSET_EOL_EXPLICIT NUMBER(38,0) COMMENT 'Indicates if EOL is explicitly set',
	ASSET_LAST_AUDIT_DATE DATE COMMENT 'Date of the last audit for the asset',
	ASSET_NEXT_AUDIT_DATE DATE COMMENT 'Date for the next scheduled audit',
	ASSET_PHYSICAL NUMBER(38,0) COMMENT 'Indicates if the asset is physical',
	ASSET_BYOD NUMBER(38,0) COMMENT 'Indicates if the asset is BYOD (Bring Your Own Device)',
	SNIPEIT_CPU_7 VARCHAR(16777216) COMMENT 'CPU specification of the asset',
	SNIPEIT_RAM_8 VARCHAR(16777216) COMMENT 'RAM size of the asset',
	SNIPEIT_DISK_TYPE_9 VARCHAR(16777216) COMMENT 'Disk type of the asset',
	SNIPEIT_DISK_SIZE_10 VARCHAR(16777216) COMMENT 'Disk size of the asset',
	SNIPEIT_DISPLAY_SIZE_11 VARCHAR(16777216) COMMENT 'Display size of the asset',
	SNIPEIT_RESOLUTION_13 VARCHAR(16777216) COMMENT 'Resolution of the asset',
	SNIPEIT_MONITOR_TYPE_14 VARCHAR(16777216) COMMENT 'Monitor type of the asset',
	SNIPEIT_REPAIR_COUNT_15 NUMBER(38,0) COMMENT 'Number of repairs done on the asset',
	ASSET_CHECKIN_COUNTER NUMBER(38,0) COMMENT 'Counter for asset check-ins',
	ASSET_CHECKOUT_COUNTER NUMBER(38,0) COMMENT 'Counter for asset check-outs',
	ASSET_REQUESTS_COUNTER NUMBER(38,0) COMMENT 'Counter for asset requests',
	ASSET_NOTES VARCHAR(16777216) COMMENT 'Additional notes or comments related to the asset'
);
""").run(output_mode="hql")

pprint(parse_results)
# Out:
# [{'alter': {},
#   'checks': [],
#   'collection_items_terminated_by': None,
#   'columns': [{'check': None,
#                'comment': "'Asset ID'",
#                'default': None,
#                'name': 'ASSET_ID',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Unique identifier for the asset'",
#                'default': None,
#                'name': 'ASSET_TAG',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the asset'",
#                'default': None,
#                'name': 'ASSET_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Serial number of the asset'",
#                'default': None,
#                'name': 'ASSET_SERIAL',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the model associated with the asset'",
#                'default': None,
#                'name': 'MODEL_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Model number of the asset'",
#                'default': None,
#                'name': 'MODEL_NUMBER',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the manufacturer of the asset'",
#                'default': None,
#                'name': 'MANUFACTURER_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Category name of the asset'",
#                'default': None,
#                'name': 'CATEGORY_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Category type of the asset'",
#                'default': None,
#                'name': 'CATEGORY_TYPE',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the asset status'",
#                'default': None,
#                'name': 'STATUS_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates whether the asset is deployable'",
#                'default': None,
#                'name': 'STATUS_DEPLOYABLE',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates whether the asset is pending'",
#                'default': None,
#                'name': 'STATUS_PENDING',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates whether the asset is archived'",
#                'default': None,
#                'name': 'STATUS_ARCHIVED',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Additional notes on the asset status'",
#                'default': None,
#                'name': 'STATUS_NOTES',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'ID of the user to whom the asset is assigned'",
#                'default': None,
#                'name': 'ASSET_ASSIGNED_TO',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'User ID associated with the asset'",
#                'default': None,
#                'name': 'ASSET_USER_ID',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Email address of the assigned user'",
#                'default': None,
#                'name': 'USER_EMAIL',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Full name of the assigned user'",
#                'default': None,
#                'name': 'FULL_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Username of the assigned user'",
#                'default': None,
#                'name': 'USERNAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'ID of the supplier who provided the asset'",
#                'default': None,
#                'name': 'SUPPLIER_ID',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the supplier'",
#                'default': None,
#                'name': 'SUPPLIER_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'ID of the company owning the asset'",
#                'default': None,
#                'name': 'COMPANY_ID',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the company'",
#                'default': None,
#                'name': 'COMPANY_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Purchase date of the asset'",
#                'default': None,
#                'name': 'ASSET_PURCHASE_DATE',
#                'nullable': True,
#                'references': None,
#                'size': None,
#                'type': 'DATE',
#                'unique': False},
#               {'check': None,
#                'comment': "'End of life date for the asset'",
#                'default': None,
#                'name': 'ASSET_EOL_DATE',
#                'nullable': True,
#                'references': None,
#                'size': None,
#                'type': 'DATE',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates if EOL is explicitly set'",
#                'default': None,
#                'name': 'ASSET_EOL_EXPLICIT',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Date of the last audit for the asset'",
#                'default': None,
#                'name': 'ASSET_LAST_AUDIT_DATE',
#                'nullable': True,
#                'references': None,
#                'size': None,
#                'type': 'DATE',
#                'unique': False},
#               {'check': None,
#                'comment': "'Date for the next scheduled audit'",
#                'default': None,
#                'name': 'ASSET_NEXT_AUDIT_DATE',
#                'nullable': True,
#                'references': None,
#                'size': None,
#                'type': 'DATE',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates if the asset is physical'",
#                'default': None,
#                'name': 'ASSET_PHYSICAL',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates if the asset is BYOD  ( Bring Your Own "
#                           "Device)'",
#                'default': None,
#                'name': 'ASSET_BYOD',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'CPU specification of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_CPU_7',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'RAM size of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_RAM_8',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Disk type of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_DISK_TYPE_9',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Disk size of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_DISK_SIZE_10',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Display size of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_DISPLAY_SIZE_11',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Resolution of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_RESOLUTION_13',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Monitor type of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_MONITOR_TYPE_14',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Number of repairs done on the asset'",
#                'default': None,
#                'name': 'SNIPEIT_REPAIR_COUNT_15',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Counter for asset check-ins'",
#                'default': None,
#                'name': 'ASSET_CHECKIN_COUNTER',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Counter for asset check-outs'",
#                'default': None,
#                'name': 'ASSET_CHECKOUT_COUNTER',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Counter for asset requests'",
#                'default': None,
#                'name': 'ASSET_REQUESTS_COUNTER',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Additional notes or comments related to the asset'",
#                'default': None,
#                'name': 'ASSET_NOTES',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False}],
#   'external': False,
#   'fields_terminated_by': None,
#   'index': [],
#   'lines_terminated_by': None,
#   'map_keys_terminated_by': None,
#   'partitioned_by': [],
#   'primary_key': [],
#   'replace': True,
#   'row_format': None,
#   'schema': 'INFRA_SCHEMA',
#   'stored_as': None,
#   'table_name': 'INFRA_ASSET_DETAILS',
#   'table_properties': {'project': 'INFRA_DB'},
#   'tablespace': None,
#   'temp': False}]

# %%
columns = parse_results["columns"]
for column in columns:
    print(column.get('name'))
# Out:
# ASSET_ID
# ASSET_TAG
# ASSET_NAME
# ASSET_SERIAL
# MODEL_NAME
# MODEL_NUMBER
# MANUFACTURER_NAME
# CATEGORY_NAME
# CATEGORY_TYPE
# STATUS_NAME
# STATUS_DEPLOYABLE
# STATUS_PENDING
# STATUS_ARCHIVED
# STATUS_NOTES
# ASSET_ASSIGNED_TO
# ASSET_USER_ID
# USER_EMAIL
# FULL_NAME
# USERNAME
# SUPPLIER_ID
# SUPPLIER_NAME
# COMPANY_ID
# COMPANY_NAME
# ASSET_PURCHASE_DATE
# ASSET_EOL_DATE
# ASSET_EOL_EXPLICIT
# ASSET_LAST_AUDIT_DATE
# ASSET_NEXT_AUDIT_DATE
# ASSET_PHYSICAL
# ASSET_BYOD
# SNIPEIT_CPU_7
# SNIPEIT_RAM_8
# SNIPEIT_DISK_TYPE_9
# SNIPEIT_DISK_SIZE_10
# SNIPEIT_DISPLAY_SIZE_11
# SNIPEIT_RESOLUTION_13
# SNIPEIT_MONITOR_TYPE_14
# SNIPEIT_REPAIR_COUNT_15
# ASSET_CHECKIN_COUNTER
# ASSET_CHECKOUT_COUNTER
# ASSET_REQUESTS_COUNTER
# ASSET_NOTES

# %%
file_path = "./assets/schema/infra_asset_details.yml"
with open(file_path,'r') as f:
    yml_file = yaml.safe_load(f)

# %% [markdown]
# ### Parse Results

# %%
for table in parse_results:
    parsed_ddl_dict  = dict()
    parsed_ddl_dict["table_name"] = table.get("table_name")
    parsed_ddl_dict["primary_keys"] = table.get("primary_keys")
    parsed_ddl_dict["columns"] = list()
    for column in table.get("columns"):
        column_dict = {
            "Name": column.get("name"),
            "Type": column.get("type"),
            "Description": column.get("comment"),
            }
        parsed_ddl_dict["columns"].append(column_dict)

# %%
for table in parse_results:
    parsed_ddl_dict = dict()
    parsed_ddl_dict.update({table["table_name"] : {
                # "primary_keys" : table.get("primary_keys")
            }})
            
    for column in table["columns"]:
        parsed_ddl_dict[table["table_name"]].update({
                column["name"] : {
                    "Type":column["type"],
                    "Description" : column["comment"]
            }})
                
pprint(parsed_ddl_dict)
# Out:
# {'INFRA_ASSET_DETAILS': {'ASSET_ASSIGNED_TO': {'Description': "'ID of the user "
#                                                               'to whom the '
#                                                               'asset is '
#                                                               "assigned'",
#                                                'Type': 'VARCHAR'},
#                          'ASSET_BYOD': {'Description': "'Indicates if the "
#                                                        'asset is BYOD  ( Bring '
#                                                        "Your Own Device)'",
#                                         'Type': 'NUMBER'},
#                          'ASSET_CHECKIN_COUNTER': {'Description': "'Counter "
#                                                                   'for asset '
#                                                                   "check-ins'",
#                                                    'Type': 'NUMBER'},
#                          'ASSET_CHECKOUT_COUNTER': {'Description': "'Counter "
#                                                                    'for asset '
#                                                                    "check-outs'",
#                                                     'Type': 'NUMBER'},
#                          'ASSET_EOL_DATE': {'Description': "'End of life date "
#                                                            "for the asset'",
#                                             'Type': 'DATE'},
#                          'ASSET_EOL_EXPLICIT': {'Description': "'Indicates if "
#                                                                'EOL is '
#                                                                'explicitly '
#                                                                "set'",
#                                                 'Type': 'NUMBER'},
#                          'ASSET_ID': {'Description': "'Asset ID'",
#                                       'Type': 'NUMBER'},
#                          'ASSET_LAST_AUDIT_DATE': {'Description': "'Date of "
#                                                                   'the last '
#                                                                   'audit for '
#                                                                   "the asset'",
#                                                    'Type': 'DATE'},
#                          'ASSET_NAME': {'Description': "'Name of the asset'",
#                                         'Type': 'VARCHAR'},
#                          'ASSET_NEXT_AUDIT_DATE': {'Description': "'Date for "
#                                                                   'the next '
#                                                                   'scheduled '
#                                                                   "audit'",
#                                                    'Type': 'DATE'},
#                          'ASSET_NOTES': {'Description': "'Additional notes or "
#                                                         'comments related to '
#                                                         "the asset'",
#                                          'Type': 'VARCHAR'},
#                          'ASSET_PHYSICAL': {'Description': "'Indicates if the "
#                                                            "asset is physical'",
#                                             'Type': 'NUMBER'},
#                          'ASSET_PURCHASE_DATE': {'Description': "'Purchase "
#                                                                 'date of the '
#                                                                 "asset'",
#                                                  'Type': 'DATE'},
#                          'ASSET_REQUESTS_COUNTER': {'Description': "'Counter "
#                                                                    'for asset '
#                                                                    "requests'",
#                                                     'Type': 'NUMBER'},
#                          'ASSET_SERIAL': {'Description': "'Serial number of "
#                                                          "the asset'",
#                                           'Type': 'VARCHAR'},
#                          'ASSET_TAG': {'Description': "'Unique identifier for "
#                                                       "the asset'",
#                                        'Type': 'VARCHAR'},
#                          'ASSET_USER_ID': {'Description': "'User ID associated "
#                                                           "with the asset'",
#                                            'Type': 'VARCHAR'},
#                          'CATEGORY_NAME': {'Description': "'Category name of "
#                                                           "the asset'",
#                                            'Type': 'VARCHAR'},
#                          'CATEGORY_TYPE': {'Description': "'Category type of "
#                                                           "the asset'",
#                                            'Type': 'VARCHAR'},
#                          'COMPANY_ID': {'Description': "'ID of the company "
#                                                        "owning the asset'",
#                                         'Type': 'VARCHAR'},
#                          'COMPANY_NAME': {'Description': "'Name of the "
#                                                          "company'",
#                                           'Type': 'VARCHAR'},
#                          'FULL_NAME': {'Description': "'Full name of the "
#                                                       "assigned user'",
#                                        'Type': 'VARCHAR'},
#                          'MANUFACTURER_NAME': {'Description': "'Name of the "
#                                                               'manufacturer of '
#                                                               "the asset'",
#                                                'Type': 'VARCHAR'},
#                          'MODEL_NAME': {'Description': "'Name of the model "
#                                                        'associated with the '
#                                                        "asset'",
#                                         'Type': 'VARCHAR'},
#                          'MODEL_NUMBER': {'Description': "'Model number of the "
#                                                          "asset'",
#                                           'Type': 'VARCHAR'},
#                          'SNIPEIT_CPU_7': {'Description': "'CPU specification "
#                                                           "of the asset'",
#                                            'Type': 'VARCHAR'},
#                          'SNIPEIT_DISK_SIZE_10': {'Description': "'Disk size "
#                                                                  'of the '
#                                                                  "asset'",
#                                                   'Type': 'VARCHAR'},
#                          'SNIPEIT_DISK_TYPE_9': {'Description': "'Disk type of "
#                                                                 "the asset'",
#                                                  'Type': 'VARCHAR'},
#                          'SNIPEIT_DISPLAY_SIZE_11': {'Description': "'Display "
#                                                                     'size of '
#                                                                     'the '
#                                                                     "asset'",
#                                                      'Type': 'VARCHAR'},
#                          'SNIPEIT_MONITOR_TYPE_14': {'Description': "'Monitor "
#                                                                     'type of '
#                                                                     'the '
#                                                                     "asset'",
#                                                      'Type': 'VARCHAR'},
#                          'SNIPEIT_RAM_8': {'Description': "'RAM size of the "
#                                                           "asset'",
#                                            'Type': 'VARCHAR'},
#                          'SNIPEIT_REPAIR_COUNT_15': {'Description': "'Number "
#                                                                     'of '
#                                                                     'repairs '
#                                                                     'done on '
#                                                                     'the '
#                                                                     "asset'",
#                                                      'Type': 'NUMBER'},
#                          'SNIPEIT_RESOLUTION_13': {'Description': "'Resolution "
#                                                                   'of the '
#                                                                   "asset'",
#                                                    'Type': 'VARCHAR'},
#                          'STATUS_ARCHIVED': {'Description': "'Indicates "
#                                                             'whether the asset '
#                                                             "is archived'",
#                                              'Type': 'NUMBER'},
#                          'STATUS_DEPLOYABLE': {'Description': "'Indicates "
#                                                               'whether the '
#                                                               'asset is '
#                                                               "deployable'",
#                                                'Type': 'NUMBER'},
#                          'STATUS_NAME': {'Description': "'Name of the asset "
#                                                         "status'",
#                                          'Type': 'VARCHAR'},
#                          'STATUS_NOTES': {'Description': "'Additional notes on "
#                                                          "the asset status'",
#                                           'Type': 'VARCHAR'},
#                          'STATUS_PENDING': {'Description': "'Indicates whether "
#                                                            'the asset is '
#                                                            "pending'",
#                                             'Type': 'NUMBER'},
#                          'SUPPLIER_ID': {'Description': "'ID of the supplier "
#                                                         'who provided the '
#                                                         "asset'",
#                                          'Type': 'VARCHAR'},
#                          'SUPPLIER_NAME': {'Description': "'Name of the "
#                                                           "supplier'",
#                                            'Type': 'VARCHAR'},
#                          'USERNAME': {'Description': "'Username of the "
#                                                      "assigned user'",
#                                       'Type': 'VARCHAR'},
#                          'USER_EMAIL': {'Description': "'Email address of the "
#                                                        "assigned user'",
#                                         'Type': 'VARCHAR'}}}

# %% [markdown]
# ### Schema

# %%
schema = yml_file.get("GeneratedSchema")
table_name = schema.get("table_info")[0].get("table")
print(table_name)
column_list = list()
for column_name, column in schema.get("columns").items():
    column_dict = {
        "Name": column.get("column"),
        "Type": column.get("type"),
        "Description" : column.get("desc")
    }
    column_list.append(column_dict)
# Out:
# INFRA_ASSET_DETAILS

# %%
pprint(column_list)
# Out:
# [{'Description': 'Asset ID', 'Name': 'ASSET_ID', 'Type': 'NUMBER'},
#  {'Description': 'Unique identifier for the asset',
#   'Name': 'ASSET_TAG',
#   'Type': 'VARCHAR'},
#  {'Description': 'Name of the asset', 'Name': 'ASSET_NAME', 'Type': 'VARCHAR'},
#  {'Description': 'Serial number of the asset',
#   'Name': 'ASSET_SERIAL',
#   'Type': 'VARCHAR'},
#  {'Description': 'Name of the model associated with the asset',
#   'Name': 'MODEL_NAME',
#   'Type': 'VARCHAR'},
#  {'Description': 'Model number of the asset',
#   'Name': 'MODEL_NUMBER',
#   'Type': 'VARCHAR'},
#  {'Description': 'Name of the manufacturer of the asset',
#   'Name': 'MANUFACTURER_NAME',
#   'Type': 'VARCHAR'},
#  {'Description': 'Category name of the asset',
#   'Name': 'CATEGORY_NAME',
#   'Type': 'VARCHAR'},
#  {'Description': 'Category type of the asset',
#   'Name': 'CATEGORY_TYPE',
#   'Type': 'VARCHAR'},
#  {'Description': 'Name of the asset status',
#   'Name': 'STATUS_NAME',
#   'Type': 'VARCHAR'},
#  {'Description': 'Indicates whether the asset is deployable',
#   'Name': 'STATUS_DEPLOYABLE',
#   'Type': 'NUMBER'},
#  {'Description': 'Indicates whether the asset is pending',
#   'Name': 'STATUS_PENDING',
#   'Type': 'NUMBER'},
#  {'Description': 'Indicates whether the asset is archived',
#   'Name': 'STATUS_ARCHIVED',
#   'Type': 'NUMBER'},
#  {'Description': 'Additional notes on the asset status',
#   'Name': 'STATUS_NOTES',
#   'Type': 'VARCHAR'},
#  {'Description': 'ID of the user to whom the asset is assigned',
#   'Name': 'ASSET_ASSIGNED_TO',
#   'Type': 'VARCHAR'},
#  {'Description': 'User ID associated with the asset',
#   'Name': 'ASSET_USER_ID',
#   'Type': 'VARCHAR'},
#  {'Description': 'Email address of the assigned user',
#   'Name': 'USER_EMAIL',
#   'Type': 'VARCHAR'},
#  {'Description': 'Full name of the assigned user',
#   'Name': 'FULL_NAME',
#   'Type': 'VARCHAR'},
#  {'Description': 'Username of the assigned user',
#   'Name': 'USERNAME',
#   'Type': 'VARCHAR'},
#  {'Description': 'ID of the supplier who provided the asset',
#   'Name': 'SUPPLIER_ID',
#   'Type': 'VARCHAR'},
#  {'Description': 'Name of the supplier',
#   'Name': 'SUPPLIER_NAME',
#   'Type': 'VARCHAR'},
#  {'Description': 'ID of the company owning the asset',
#   'Name': 'COMPANY_ID',
#   'Type': 'VARCHAR'},
#  {'Description': 'Name of the company',
#   'Name': 'COMPANY_NAME',
#   'Type': 'VARCHAR'},
#  {'Description': 'Purchase date of the asset',
#   'Name': 'ASSET_PURCHASE_DATE',
#   'Type': 'DATE'},
#  {'Description': 'End of life date for the asset',
#   'Name': 'ASSET_EOL_DATE',
#   'Type': 'DATE'},
#  {'Description': 'Indicates if EOL is explicitly set',
#   'Name': 'ASSET_EOL_EXPLICIT',
#   'Type': 'NUMBER'},
#  {'Description': 'Date of the last audit for the asset',
#   'Name': 'ASSET_LAST_AUDIT_DATE',
#   'Type': 'DATE'},
#  {'Description': 'Date for the next scheduled audit',
#   'Name': 'ASSET_NEXT_AUDIT_DATE',
#   'Type': 'DATE'},
#  {'Description': 'Indicates if the asset is physical',
#   'Name': 'ASSET_PHYSICAL',
#   'Type': 'NUMBER'},
#  {'Description': 'Indicates if the asset is BYOD  ( Bring Your Own Device)',
#   'Name': 'ASSET_BYOD',
#   'Type': 'NUMBER'},
#  {'Description': 'CPU specification of the asset',
#   'Name': 'SNIPEIT_CPU_7',
#   'Type': 'VARCHAR'},
#  {'Description': 'RAM size of the asset',
#   'Name': 'SNIPEIT_RAM_8',
#   'Type': 'VARCHAR'},
#  {'Description': 'Disk type of the asset',
#   'Name': 'SNIPEIT_DISK_TYPE_9',
#   'Type': 'VARCHAR'},
#  {'Description': 'Disk size of the asset',
#   'Name': 'SNIPEIT_DISK_SIZE_10',
#   'Type': 'VARCHAR'},
#  {'Description': 'Display size of the asset',
#   'Name': 'SNIPEIT_DISPLAY_SIZE_11',
#   'Type': 'VARCHAR'},
#  {'Description': 'Resolution of the asset',
#   'Name': 'SNIPEIT_RESOLUTION_13',
#   'Type': 'VARCHAR'},
#  {'Description': 'Monitor type of the asset',
#   'Name': 'SNIPEIT_MONITOR_TYPE_14',
#   'Type': 'VARCHAR'},
#  {'Description': 'Number of repairs done on the asset',
#   'Name': 'SNIPEIT_REPAIR_COUNT_15',
#   'Type': 'NUMBER'},
#  {'Description': 'Counter for asset check-ins',
#   'Name': 'ASSET_CHECKIN_COUNTER',
#   'Type': 'NUMBER'},
#  {'Description': 'Counter for asset check-outs',
#   'Name': 'ASSET_CHECKOUT_COUNTER',
#   'Type': 'NUMBER'},
#  {'Description': 'Counter for asset requests',
#   'Name': 'ASSET_REQUESTS_COUNTER',
#   'Type': 'NUMBER'},
#  {'Description': 'Additional notes or comments related to the asset',
#   'Name': 'ASSET_NOTES',
#   'Type': 'VARCHAR'}]

# %%
pprint(parsed_ddl_dict)
# Out:
# {'columns': [{'Description': "'Asset ID'",
#               'Name': 'ASSET_ID',
#               'Type': 'NUMBER'},
#              {'Description': "'Unique identifier for the asset'",
#               'Name': 'ASSET_TAG',
#               'Type': 'VARCHAR'},
#              {'Description': "'Name of the asset'",
#               'Name': 'ASSET_NAME',
#               'Type': 'VARCHAR'},
#              {'Description': "'Serial number of the asset'",
#               'Name': 'ASSET_SERIAL',
#               'Type': 'VARCHAR'},
#              {'Description': "'Name of the model associated with the asset'",
#               'Name': 'MODEL_NAME',
#               'Type': 'VARCHAR'},
#              {'Description': "'Model number of the asset'",
#               'Name': 'MODEL_NUMBER',
#               'Type': 'VARCHAR'},
#              {'Description': "'Name of the manufacturer of the asset'",
#               'Name': 'MANUFACTURER_NAME',
#               'Type': 'VARCHAR'},
#              {'Description': "'Category name of the asset'",
#               'Name': 'CATEGORY_NAME',
#               'Type': 'VARCHAR'},
#              {'Description': "'Category type of the asset'",
#               'Name': 'CATEGORY_TYPE',
#               'Type': 'VARCHAR'},
#              {'Description': "'Name of the asset status'",
#               'Name': 'STATUS_NAME',
#               'Type': 'VARCHAR'},
#              {'Description': "'Indicates whether the asset is deployable'",
#               'Name': 'STATUS_DEPLOYABLE',
#               'Type': 'NUMBER'},
#              {'Description': "'Indicates whether the asset is pending'",
#               'Name': 'STATUS_PENDING',
#               'Type': 'NUMBER'},
#              {'Description': "'Indicates whether the asset is archived'",
#               'Name': 'STATUS_ARCHIVED',
#               'Type': 'NUMBER'},
#              {'Description': "'Additional notes on the asset status'",
#               'Name': 'STATUS_NOTES',
#               'Type': 'VARCHAR'},
#              {'Description': "'ID of the user to whom the asset is assigned'",
#               'Name': 'ASSET_ASSIGNED_TO',
#               'Type': 'VARCHAR'},
#              {'Description': "'User ID associated with the asset'",
#               'Name': 'ASSET_USER_ID',
#               'Type': 'VARCHAR'},
#              {'Description': "'Email address of the assigned user'",
#               'Name': 'USER_EMAIL',
#               'Type': 'VARCHAR'},
#              {'Description': "'Full name of the assigned user'",
#               'Name': 'FULL_NAME',
#               'Type': 'VARCHAR'},
#              {'Description': "'Username of the assigned user'",
#               'Name': 'USERNAME',
#               'Type': 'VARCHAR'},
#              {'Description': "'ID of the supplier who provided the asset'",
#               'Name': 'SUPPLIER_ID',
#               'Type': 'VARCHAR'},
#              {'Description': "'Name of the supplier'",
#               'Name': 'SUPPLIER_NAME',
#               'Type': 'VARCHAR'},
#              {'Description': "'ID of the company owning the asset'",
#               'Name': 'COMPANY_ID',
#               'Type': 'VARCHAR'},
#              {'Description': "'Name of the company'",
#               'Name': 'COMPANY_NAME',
#               'Type': 'VARCHAR'},
#              {'Description': "'Purchase date of the asset'",
#               'Name': 'ASSET_PURCHASE_DATE',
#               'Type': 'DATE'},
#              {'Description': "'End of life date for the asset'",
#               'Name': 'ASSET_EOL_DATE',
#               'Type': 'DATE'},
#              {'Description': "'Indicates if EOL is explicitly set'",
#               'Name': 'ASSET_EOL_EXPLICIT',
#               'Type': 'NUMBER'},
#              {'Description': "'Date of the last audit for the asset'",
#               'Name': 'ASSET_LAST_AUDIT_DATE',
#               'Type': 'DATE'},
#              {'Description': "'Date for the next scheduled audit'",
#               'Name': 'ASSET_NEXT_AUDIT_DATE',
#               'Type': 'DATE'},
#              {'Description': "'Indicates if the asset is physical'",
#               'Name': 'ASSET_PHYSICAL',
#               'Type': 'NUMBER'},
#              {'Description': "'Indicates if the asset is BYOD  ( Bring Your "
#                              "Own Device)'",
#               'Name': 'ASSET_BYOD',
#               'Type': 'NUMBER'},
#              {'Description': "'CPU specification of the asset'",
#               'Name': 'SNIPEIT_CPU_7',
#               'Type': 'VARCHAR'},
#              {'Description': "'RAM size of the asset'",
#               'Name': 'SNIPEIT_RAM_8',
#               'Type': 'VARCHAR'},
#              {'Description': "'Disk type of the asset'",
#               'Name': 'SNIPEIT_DISK_TYPE_9',
#               'Type': 'VARCHAR'},
#              {'Description': "'Disk size of the asset'",
#               'Name': 'SNIPEIT_DISK_SIZE_10',
#               'Type': 'VARCHAR'},
#              {'Description': "'Display size of the asset'",
#               'Name': 'SNIPEIT_DISPLAY_SIZE_11',
#               'Type': 'VARCHAR'},
#              {'Description': "'Resolution of the asset'",
#               'Name': 'SNIPEIT_RESOLUTION_13',
#               'Type': 'VARCHAR'},
#              {'Description': "'Monitor type of the asset'",
#               'Name': 'SNIPEIT_MONITOR_TYPE_14',
#               'Type': 'VARCHAR'},
#              {'Description': "'Number of repairs done on the asset'",
#               'Name': 'SNIPEIT_REPAIR_COUNT_15',
#               'Type': 'NUMBER'},
#              {'Description': "'Counter for asset check-ins'",
#               'Name': 'ASSET_CHECKIN_COUNTER',
#               'Type': 'NUMBER'},
#              {'Description': "'Counter for asset check-outs'",
#               'Name': 'ASSET_CHECKOUT_COUNTER',
#               'Type': 'NUMBER'},
#              {'Description': "'Counter for asset requests'",
#               'Name': 'ASSET_REQUESTS_COUNTER',
#               'Type': 'NUMBER'},
#              {'Description': "'Additional notes or comments related to the "
#                              "asset'",
#               'Name': 'ASSET_NOTES',
#               'Type': 'VARCHAR'}],
#  'primary_keys': None,
#  'table_name': 'INFRA_ASSET_DETAILS'}
