# %%
import yaml
from simple_ddl_parser.parser import Parser

# %%
from simple_ddl_parser import DDLParser
from pprint import pprint

parse_results = DDLParser("""create or replace TABLE INFRA_DB.INFRA_SCHEMA.INFRA_ASSET_DETAILS (
	ASSET_ID NUMBER(38,0) COMMENT 'Asset ID',
	ASSET_TAG VARCHAR(16777216) COMMENT 'Unique identifier for the asset',
	ASSET_NAME VARCHAR(16777216) COMMENT 'Name of the asset',
	ASSET_SERIAL VARCHAR(16777216) COMMENT 'Serial number of the asset',
	MODEL_NAME VARCHAR(16777216) COMMENT 'Name of the model associated with the asset',
	MODEL_NUMBER VARCHAR(16777216) COMMENT 'Model number of the asset',
	MANUFACTURER_NAME VARCHAR(16777216) COMMENT 'Name of the manufacturer of the asset',
	CATEGORY_NAME VARCHAR(16777216) COMMENT 'Category name of the asset',
	CATEGORY_TYPE VARCHAR(16777216) COMMENT 'Category type of the asset',
	STATUS_NAME VARCHAR(16777216) COMMENT 'Name of the asset status',
	STATUS_DEPLOYABLE NUMBER(38,0) COMMENT 'Indicates whether the asset is deployable',
	STATUS_PENDING NUMBER(38,0) COMMENT 'Indicates whether the asset is pending',
	STATUS_ARCHIVED NUMBER(38,0) COMMENT 'Indicates whether the asset is archived',
	STATUS_NOTES VARCHAR(16777216) COMMENT 'Additional notes on the asset status',
	ASSET_ASSIGNED_TO VARCHAR(16777216) COMMENT 'ID of the user to whom the asset is assigned',
	ASSET_USER_ID VARCHAR(16777216) COMMENT 'User ID associated with the asset',
	USER_EMAIL VARCHAR(16777216) COMMENT 'Email address of the assigned user',
	FULL_NAME VARCHAR(16777216) COMMENT 'Full name of the assigned user',
	USERNAME VARCHAR(16777216) COMMENT 'Username of the assigned user',
	SUPPLIER_ID VARCHAR(16777216) COMMENT 'ID of the supplier who provided the asset',
	SUPPLIER_NAME VARCHAR(16777216) COMMENT 'Name of the supplier',
	COMPANY_ID VARCHAR(16777216) COMMENT 'ID of the company owning the asset',
	COMPANY_NAME VARCHAR(16777216) COMMENT 'Name of the company',
	ASSET_PURCHASE_DATE DATE COMMENT 'Purchase date of the asset',
	ASSET_EOL_DATE DATE COMMENT 'End of life date for the asset',
	ASSET_EOL_EXPLICIT NUMBER(38,0) COMMENT 'Indicates if EOL is explicitly set',
	ASSET_LAST_AUDIT_DATE DATE COMMENT 'Date of the last audit for the asset',
	ASSET_NEXT_AUDIT_DATE DATE COMMENT 'Date for the next scheduled audit',
	ASSET_PHYSICAL NUMBER(38,0) COMMENT 'Indicates if the asset is physical',
	ASSET_BYOD NUMBER(38,0) COMMENT 'Indicates if the asset is BYOD (Bring Your Own Device)',
	SNIPEIT_CPU_7 VARCHAR(16777216) COMMENT 'CPU specification of the asset',
	SNIPEIT_RAM_8 VARCHAR(16777216) COMMENT 'RAM size of the asset',
	SNIPEIT_DISK_TYPE_9 VARCHAR(16777216) COMMENT 'Disk type of the asset',
	SNIPEIT_DISK_SIZE_10 VARCHAR(16777216) COMMENT 'Disk size of the asset',
	SNIPEIT_DISPLAY_SIZE_11 VARCHAR(16777216) COMMENT 'Display size of the asset',
	SNIPEIT_RESOLUTION_13 VARCHAR(16777216) COMMENT 'Resolution of the asset',
	SNIPEIT_MONITOR_TYPE_14 VARCHAR(16777216) COMMENT 'Monitor type of the asset',
	SNIPEIT_REPAIR_COUNT_15 NUMBER(38,0) COMMENT 'Number of repairs done on the asset',
	ASSET_CHECKIN_COUNTER NUMBER(38,0) COMMENT 'Counter for asset check-ins',
	ASSET_CHECKOUT_COUNTER NUMBER(38,0) COMMENT 'Counter for asset check-outs',
	ASSET_REQUESTS_COUNTER NUMBER(38,0) COMMENT 'Counter for asset requests',
	ASSET_NOTES VARCHAR(16777216) COMMENT 'Additional notes or comments related to the asset'
);
""").run()

pprint(parse_results)
# Out:
# [{'alter': {},
#   'checks': [],
#   'columns': [{'check': None,
#                'comment': "'Asset ID'",
#                'default': None,
#                'name': 'ASSET_ID',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Unique identifier for the asset'",
#                'default': None,
#                'name': 'ASSET_TAG',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the asset'",
#                'default': None,
#                'name': 'ASSET_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Serial number of the asset'",
#                'default': None,
#                'name': 'ASSET_SERIAL',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the model associated with the asset'",
#                'default': None,
#                'name': 'MODEL_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Model number of the asset'",
#                'default': None,
#                'name': 'MODEL_NUMBER',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the manufacturer of the asset'",
#                'default': None,
#                'name': 'MANUFACTURER_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Category name of the asset'",
#                'default': None,
#                'name': 'CATEGORY_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Category type of the asset'",
#                'default': None,
#                'name': 'CATEGORY_TYPE',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the asset status'",
#                'default': None,
#                'name': 'STATUS_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates whether the asset is deployable'",
#                'default': None,
#                'name': 'STATUS_DEPLOYABLE',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates whether the asset is pending'",
#                'default': None,
#                'name': 'STATUS_PENDING',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates whether the asset is archived'",
#                'default': None,
#                'name': 'STATUS_ARCHIVED',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Additional notes on the asset status'",
#                'default': None,
#                'name': 'STATUS_NOTES',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'ID of the user to whom the asset is assigned'",
#                'default': None,
#                'name': 'ASSET_ASSIGNED_TO',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'User ID associated with the asset'",
#                'default': None,
#                'name': 'ASSET_USER_ID',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Email address of the assigned user'",
#                'default': None,
#                'name': 'USER_EMAIL',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Full name of the assigned user'",
#                'default': None,
#                'name': 'FULL_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Username of the assigned user'",
#                'default': None,
#                'name': 'USERNAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'ID of the supplier who provided the asset'",
#                'default': None,
#                'name': 'SUPPLIER_ID',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the supplier'",
#                'default': None,
#                'name': 'SUPPLIER_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'ID of the company owning the asset'",
#                'default': None,
#                'name': 'COMPANY_ID',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the company'",
#                'default': None,
#                'name': 'COMPANY_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Purchase date of the asset'",
#                'default': None,
#                'name': 'ASSET_PURCHASE_DATE',
#                'nullable': True,
#                'references': None,
#                'size': None,
#                'type': 'DATE',
#                'unique': False},
#               {'check': None,
#                'comment': "'End of life date for the asset'",
#                'default': None,
#                'name': 'ASSET_EOL_DATE',
#                'nullable': True,
#                'references': None,
#                'size': None,
#                'type': 'DATE',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates if EOL is explicitly set'",
#                'default': None,
#                'name': 'ASSET_EOL_EXPLICIT',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Date of the last audit for the asset'",
#                'default': None,
#                'name': 'ASSET_LAST_AUDIT_DATE',
#                'nullable': True,
#                'references': None,
#                'size': None,
#                'type': 'DATE',
#                'unique': False},
#               {'check': None,
#                'comment': "'Date for the next scheduled audit'",
#                'default': None,
#                'name': 'ASSET_NEXT_AUDIT_DATE',
#                'nullable': True,
#                'references': None,
#                'size': None,
#                'type': 'DATE',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates if the asset is physical'",
#                'default': None,
#                'name': 'ASSET_PHYSICAL',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates if the asset is BYOD  ( Bring Your Own "
#                           "Device)'",
#                'default': None,
#                'name': 'ASSET_BYOD',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'CPU specification of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_CPU_7',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'RAM size of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_RAM_8',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Disk type of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_DISK_TYPE_9',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Disk size of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_DISK_SIZE_10',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Display size of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_DISPLAY_SIZE_11',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Resolution of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_RESOLUTION_13',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Monitor type of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_MONITOR_TYPE_14',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Number of repairs done on the asset'",
#                'default': None,
#                'name': 'SNIPEIT_REPAIR_COUNT_15',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Counter for asset check-ins'",
#                'default': None,
#                'name': 'ASSET_CHECKIN_COUNTER',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Counter for asset check-outs'",
#                'default': None,
#                'name': 'ASSET_CHECKOUT_COUNTER',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Counter for asset requests'",
#                'default': None,
#                'name': 'ASSET_REQUESTS_COUNTER',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Additional notes or comments related to the asset'",
#                'default': None,
#                'name': 'ASSET_NOTES',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False}],
#   'index': [],
#   'partitioned_by': [],
#   'primary_key': [],
#   'replace': True,
#   'schema': 'INFRA_SCHEMA',
#   'table_name': 'INFRA_ASSET_DETAILS',
#   'table_properties': {'project': 'INFRA_DB'},
#   'tablespace': None}]

# %%
file_path = "./assets/schema/infra_asset_details.yml"
with open(file_path,'r') as f:
    yml_file = yaml.safe_load(f)

# %%
pprint(yml_file)
# Out:
# {'GeneratedSchema': {'columns': {'ASSET_ASSIGNED_TO': {'column': 'ASSET_ASSIGNED_TO',
#                                                        'desc': 'ID of the user '
#                                                                'to whom the '
#                                                                'asset is '
#                                                                'assigned',
#                                                        'foreign_key': True,
#                                                        'name': 'Asset Assigned '
#                                                                'To',
#                                                        'primary_key': False,
#                                                        'type': 'VARCHAR'},
#                                  'ASSET_BYOD': {'column': 'ASSET_BYOD',
#                                                 'desc': 'Indicates if the '
#                                                         'asset is BYOD  ( '
#                                                         'Bring Your Own '
#                                                         'Device)',
#                                                 'foreign_key': False,
#                                                 'name': 'Asset BYOD',
#                                                 'primary_key': False,
#                                                 'type': 'NUMBER'},
#                                  'ASSET_CHECKIN_COUNTER': {'column': 'ASSET_CHECKIN_COUNTER',
#                                                            'desc': 'Counter '
#                                                                    'for asset '
#                                                                    'check-ins',
#                                                            'foreign_key': False,
#                                                            'name': 'Asset '
#                                                                    'Check-in '
#                                                                    'Counter',
#                                                            'primary_key': False,
#                                                            'type': 'NUMBER'},
#                                  'ASSET_CHECKOUT_COUNTER': {'column': 'ASSET_CHECKOUT_COUNTER',
#                                                             'desc': 'Counter '
#                                                                     'for asset '
#                                                                     'check-outs',
#                                                             'foreign_key': False,
#                                                             'name': 'Asset '
#                                                                     'Check-out '
#                                                                     'Counter',
#                                                             'primary_key': False,
#                                                             'type': 'NUMBER'},
#                                  'ASSET_EOL_DATE': {'column': 'ASSET_EOL_DATE',
#                                                     'desc': 'End of life date '
#                                                             'for the asset',
#                                                     'foreign_key': False,
#                                                     'name': 'Asset EOL Date',
#                                                     'primary_key': False,
#                                                     'type': 'DATE'},
#                                  'ASSET_EOL_EXPLICIT': {'column': 'ASSET_EOL_EXPLICIT',
#                                                         'desc': 'Indicates if '
#                                                                 'EOL is '
#                                                                 'explicitly '
#                                                                 'set',
#                                                         'foreign_key': False,
#                                                         'name': 'Asset EOL '
#                                                                 'Explicit',
#                                                         'primary_key': False,
#                                                         'type': 'NUMBER'},
#                                  'ASSET_ID': {'column': 'ASSET_ID',
#                                               'desc': 'Asset ID',
#                                               'foreign_key': False,
#                                               'name': 'Asset ID',
#                                               'primary_key': False,
#                                               'type': 'NUMBER'},
#                                  'ASSET_LAST_AUDIT_DATE': {'column': 'ASSET_LAST_AUDIT_DATE',
#                                                            'desc': 'Date of '
#                                                                    'the last '
#                                                                    'audit for '
#                                                                    'the asset',
#                                                            'foreign_key': False,
#                                                            'name': 'Asset Last '
#                                                                    'Audit Date',
#                                                            'primary_key': False,
#                                                            'type': 'DATE'},
#                                  'ASSET_NAME': {'column': 'ASSET_NAME',
#                                                 'desc': 'Name of the asset',
#                                                 'foreign_key': False,
#                                                 'name': 'Asset Name',
#                                                 'primary_key': False,
#                                                 'type': 'VARCHAR'},
#                                  'ASSET_NEXT_AUDIT_DATE': {'column': 'ASSET_NEXT_AUDIT_DATE',
#                                                            'desc': 'Date for '
#                                                                    'the next '
#                                                                    'scheduled '
#                                                                    'audit',
#                                                            'foreign_key': False,
#                                                            'name': 'Asset Next '
#                                                                    'Audit Date',
#                                                            'primary_key': False,
#                                                            'type': 'DATE'},
#                                  'ASSET_NOTES': {'column': 'ASSET_NOTES',
#                                                  'desc': 'Additional notes or '
#                                                          'comments related to '
#                                                          'the asset',
#                                                  'foreign_key': False,
#                                                  'name': 'Asset Notes',
#                                                  'primary_key': False,
#                                                  'type': 'VARCHAR'},
#                                  'ASSET_PHYSICAL': {'column': 'ASSET_PHYSICAL',
#                                                     'desc': 'Indicates if the '
#                                                             'asset is physical',
#                                                     'foreign_key': False,
#                                                     'name': 'Asset Physical',
#                                                     'primary_key': False,
#                                                     'type': 'NUMBER'},
#                                  'ASSET_PURCHASE_DATE': {'column': 'ASSET_PURCHASE_DATE',
#                                                          'desc': 'Purchase '
#                                                                  'date of the '
#                                                                  'asset',
#                                                          'foreign_key': False,
#                                                          'name': 'Asset '
#                                                                  'Purchase '
#                                                                  'Date',
#                                                          'primary_key': False,
#                                                          'type': 'DATE'},
#                                  'ASSET_REQUESTS_COUNTER': {'column': 'ASSET_REQUESTS_COUNTER',
#                                                             'desc': 'Counter '
#                                                                     'for asset '
#                                                                     'requests',
#                                                             'foreign_key': False,
#                                                             'name': 'Asset '
#                                                                     'Requests '
#                                                                     'Counter',
#                                                             'primary_key': False,
#                                                             'type': 'NUMBER'},
#                                  'ASSET_SERIAL': {'column': 'ASSET_SERIAL',
#                                                   'desc': 'Serial number of '
#                                                           'the asset',
#                                                   'foreign_key': False,
#                                                   'name': 'Asset Serial',
#                                                   'primary_key': False,
#                                                   'type': 'VARCHAR'},
#                                  'ASSET_TAG': {'column': 'ASSET_TAG',
#                                                'desc': 'Unique identifier for '
#                                                        'the asset',
#                                                'foreign_key': False,
#                                                'name': 'Asset Tag',
#                                                'primary_key': False,
#                                                'type': 'VARCHAR'},
#                                  'ASSET_USER_ID': {'column': 'ASSET_USER_ID',
#                                                    'desc': 'User ID associated '
#                                                            'with the asset',
#                                                    'foreign_key': True,
#                                                    'name': 'Asset User ID',
#                                                    'primary_key': False,
#                                                    'type': 'VARCHAR'},
#                                  'CATEGORY_NAME': {'column': 'CATEGORY_NAME',
#                                                    'desc': 'Category name of '
#                                                            'the asset',
#                                                    'foreign_key': False,
#                                                    'name': 'Category Name',
#                                                    'primary_key': False,
#                                                    'type': 'VARCHAR'},
#                                  'CATEGORY_TYPE': {'column': 'CATEGORY_TYPE',
#                                                    'desc': 'Category type of '
#                                                            'the asset',
#                                                    'foreign_key': False,
#                                                    'name': 'Category Type',
#                                                    'primary_key': False,
#                                                    'type': 'VARCHAR'},
#                                  'COMPANY_ID': {'column': 'COMPANY_ID',
#                                                 'desc': 'ID of the company '
#                                                         'owning the asset',
#                                                 'foreign_key': True,
#                                                 'name': 'Company ID',
#                                                 'primary_key': False,
#                                                 'type': 'VARCHAR'},
#                                  'COMPANY_NAME': {'column': 'COMPANY_NAME',
#                                                   'desc': 'Name of the company',
#                                                   'foreign_key': False,
#                                                   'name': 'Company Name',
#                                                   'primary_key': False,
#                                                   'type': 'VARCHAR'},
#                                  'FULL_NAME': {'column': 'FULL_NAME',
#                                                'desc': 'Full name of the '
#                                                        'assigned user',
#                                                'foreign_key': False,
#                                                'name': 'Full Name',
#                                                'primary_key': False,
#                                                'type': 'VARCHAR'},
#                                  'MANUFACTURER_NAME': {'column': 'MANUFACTURER_NAME',
#                                                        'desc': 'Name of the '
#                                                                'manufacturer '
#                                                                'of the asset',
#                                                        'foreign_key': False,
#                                                        'name': 'Manufacturer '
#                                                                'Name',
#                                                        'primary_key': False,
#                                                        'type': 'VARCHAR'},
#                                  'MODEL_NAME': {'column': 'MODEL_NAME',
#                                                 'desc': 'Name of the model '
#                                                         'associated with the '
#                                                         'asset',
#                                                 'foreign_key': False,
#                                                 'name': 'Model Name',
#                                                 'primary_key': False,
#                                                 'type': 'VARCHAR'},
#                                  'MODEL_NUMBER': {'column': 'MODEL_NUMBER',
#                                                   'desc': 'Model number of the '
#                                                           'asset',
#                                                   'foreign_key': False,
#                                                   'name': 'Model Number',
#                                                   'primary_key': False,
#                                                   'type': 'VARCHAR'},
#                                  'SNIPEIT_CPU_7': {'column': 'SNIPEIT_CPU_7',
#                                                    'desc': 'CPU specification '
#                                                            'of the asset',
#                                                    'foreign_key': False,
#                                                    'name': 'SnipeIT CPU',
#                                                    'primary_key': False,
#                                                    'type': 'VARCHAR'},
#                                  'SNIPEIT_DISK_SIZE_10': {'column': 'SNIPEIT_DISK_SIZE_10',
#                                                           'desc': 'Disk size '
#                                                                   'of the '
#                                                                   'asset',
#                                                           'foreign_key': False,
#                                                           'name': 'SnipeIT '
#                                                                   'Disk Size',
#                                                           'primary_key': False,
#                                                           'type': 'VARCHAR'},
#                                  'SNIPEIT_DISK_TYPE_9': {'column': 'SNIPEIT_DISK_TYPE_9',
#                                                          'desc': 'Disk type of '
#                                                                  'the asset',
#                                                          'foreign_key': False,
#                                                          'name': 'SnipeIT Disk '
#                                                                  'Type',
#                                                          'primary_key': False,
#                                                          'type': 'VARCHAR'},
#                                  'SNIPEIT_DISPLAY_SIZE_11': {'column': 'SNIPEIT_DISPLAY_SIZE_11',
#                                                              'desc': 'Display '
#                                                                      'size of '
#                                                                      'the '
#                                                                      'asset',
#                                                              'foreign_key': False,
#                                                              'name': 'SnipeIT '
#                                                                      'Display '
#                                                                      'Size',
#                                                              'primary_key': False,
#                                                              'type': 'VARCHAR'},
#                                  'SNIPEIT_MONITOR_TYPE_14': {'column': 'SNIPEIT_MONITOR_TYPE_14',
#                                                              'desc': 'Monitor '
#                                                                      'type of '
#                                                                      'the '
#                                                                      'asset',
#                                                              'foreign_key': False,
#                                                              'name': 'SnipeIT '
#                                                                      'Monitor '
#                                                                      'Type',
#                                                              'primary_key': False,
#                                                              'type': 'VARCHAR'},
#                                  'SNIPEIT_RAM_8': {'column': 'SNIPEIT_RAM_8',
#                                                    'desc': 'RAM size of the '
#                                                            'asset',
#                                                    'foreign_key': False,
#                                                    'name': 'SnipeIT RAM',
#                                                    'primary_key': False,
#                                                    'type': 'VARCHAR'},
#                                  'SNIPEIT_REPAIR_COUNT_15': {'column': 'SNIPEIT_REPAIR_COUNT_15',
#                                                              'desc': 'Number '
#                                                                      'of '
#                                                                      'repairs '
#                                                                      'done on '
#                                                                      'the '
#                                                                      'asset',
#                                                              'foreign_key': False,
#                                                              'name': 'SnipeIT '
#                                                                      'Repair '
#                                                                      'Count',
#                                                              'primary_key': False,
#                                                              'type': 'NUMBER'},
#                                  'SNIPEIT_RESOLUTION_13': {'column': 'SNIPEIT_RESOLUTION_13',
#                                                            'desc': 'Resolution '
#                                                                    'of the '
#                                                                    'asset',
#                                                            'foreign_key': False,
#                                                            'name': 'SnipeIT '
#                                                                    'Resolution',
#                                                            'primary_key': False,
#                                                            'type': 'VARCHAR'},
#                                  'STATUS_ARCHIVED': {'column': 'STATUS_ARCHIVED',
#                                                      'desc': 'Indicates '
#                                                              'whether the '
#                                                              'asset is '
#                                                              'archived',
#                                                      'foreign_key': False,
#                                                      'name': 'Status Archived',
#                                                      'primary_key': False,
#                                                      'type': 'NUMBER'},
#                                  'STATUS_DEPLOYABLE': {'column': 'STATUS_DEPLOYABLE',
#                                                        'desc': 'Indicates '
#                                                                'whether the '
#                                                                'asset is '
#                                                                'deployable',
#                                                        'foreign_key': False,
#                                                        'name': 'Status '
#                                                                'Deployable',
#                                                        'primary_key': False,
#                                                        'type': 'NUMBER'},
#                                  'STATUS_NAME': {'column': 'STATUS_NAME',
#                                                  'desc': 'Name of the asset '
#                                                          'status',
#                                                  'foreign_key': False,
#                                                  'name': 'Status Name',
#                                                  'primary_key': False,
#                                                  'type': 'VARCHAR'},
#                                  'STATUS_NOTES': {'column': 'STATUS_NOTES',
#                                                   'desc': 'Additional notes on '
#                                                           'the asset status',
#                                                   'foreign_key': False,
#                                                   'name': 'Status Notes',
#                                                   'primary_key': False,
#                                                   'type': 'VARCHAR'},
#                                  'STATUS_PENDING': {'column': 'STATUS_PENDING',
#                                                     'desc': 'Indicates whether '
#                                                             'the asset is '
#                                                             'pending',
#                                                     'foreign_key': False,
#                                                     'name': 'Status Pending',
#                                                     'primary_key': False,
#                                                     'type': 'NUMBER'},
#                                  'SUPPLIER_ID': {'column': 'SUPPLIER_ID',
#                                                  'desc': 'ID of the supplier '
#                                                          'who provided the '
#                                                          'asset',
#                                                  'foreign_key': True,
#                                                  'name': 'Supplier ID',
#                                                  'primary_key': False,
#                                                  'type': 'VARCHAR'},
#                                  'SUPPLIER_NAME': {'column': 'SUPPLIER_NAME',
#                                                    'desc': 'Name of the '
#                                                            'supplier',
#                                                    'foreign_key': False,
#                                                    'name': 'Supplier Name',
#                                                    'primary_key': False,
#                                                    'type': 'VARCHAR'},
#                                  'USERNAME': {'column': 'USERNAME',
#                                               'desc': 'Username of the '
#                                                       'assigned user',
#                                               'foreign_key': False,
#                                               'name': 'Username',
#                                               'primary_key': False,
#                                               'type': 'VARCHAR'},
#                                  'USER_EMAIL': {'column': 'USER_EMAIL',
#                                                 'desc': 'Email address of the '
#                                                         'assigned user',
#                                                 'foreign_key': False,
#                                                 'name': 'User Email',
#                                                 'primary_key': False,
#                                                 'type': 'VARCHAR'}},
#                      'subject_area': 'Asset Management',
#                      'table_info': [{'joins': [],
#                                      'table': 'INFRA_ASSET_DETAILS'}]}}

# %%
pprint(parse_results)
# Out:
# [{'alter': {},
#   'checks': [],
#   'columns': [{'check': None,
#                'comment': "'Asset ID'",
#                'default': None,
#                'name': 'ASSET_ID',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Unique identifier for the asset'",
#                'default': None,
#                'name': 'ASSET_TAG',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the asset'",
#                'default': None,
#                'name': 'ASSET_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Serial number of the asset'",
#                'default': None,
#                'name': 'ASSET_SERIAL',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the model associated with the asset'",
#                'default': None,
#                'name': 'MODEL_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Model number of the asset'",
#                'default': None,
#                'name': 'MODEL_NUMBER',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the manufacturer of the asset'",
#                'default': None,
#                'name': 'MANUFACTURER_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Category name of the asset'",
#                'default': None,
#                'name': 'CATEGORY_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Category type of the asset'",
#                'default': None,
#                'name': 'CATEGORY_TYPE',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the asset status'",
#                'default': None,
#                'name': 'STATUS_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates whether the asset is deployable'",
#                'default': None,
#                'name': 'STATUS_DEPLOYABLE',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates whether the asset is pending'",
#                'default': None,
#                'name': 'STATUS_PENDING',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates whether the asset is archived'",
#                'default': None,
#                'name': 'STATUS_ARCHIVED',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Additional notes on the asset status'",
#                'default': None,
#                'name': 'STATUS_NOTES',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'ID of the user to whom the asset is assigned'",
#                'default': None,
#                'name': 'ASSET_ASSIGNED_TO',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'User ID associated with the asset'",
#                'default': None,
#                'name': 'ASSET_USER_ID',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Email address of the assigned user'",
#                'default': None,
#                'name': 'USER_EMAIL',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Full name of the assigned user'",
#                'default': None,
#                'name': 'FULL_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Username of the assigned user'",
#                'default': None,
#                'name': 'USERNAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'ID of the supplier who provided the asset'",
#                'default': None,
#                'name': 'SUPPLIER_ID',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the supplier'",
#                'default': None,
#                'name': 'SUPPLIER_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'ID of the company owning the asset'",
#                'default': None,
#                'name': 'COMPANY_ID',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Name of the company'",
#                'default': None,
#                'name': 'COMPANY_NAME',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Purchase date of the asset'",
#                'default': None,
#                'name': 'ASSET_PURCHASE_DATE',
#                'nullable': True,
#                'references': None,
#                'size': None,
#                'type': 'DATE',
#                'unique': False},
#               {'check': None,
#                'comment': "'End of life date for the asset'",
#                'default': None,
#                'name': 'ASSET_EOL_DATE',
#                'nullable': True,
#                'references': None,
#                'size': None,
#                'type': 'DATE',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates if EOL is explicitly set'",
#                'default': None,
#                'name': 'ASSET_EOL_EXPLICIT',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Date of the last audit for the asset'",
#                'default': None,
#                'name': 'ASSET_LAST_AUDIT_DATE',
#                'nullable': True,
#                'references': None,
#                'size': None,
#                'type': 'DATE',
#                'unique': False},
#               {'check': None,
#                'comment': "'Date for the next scheduled audit'",
#                'default': None,
#                'name': 'ASSET_NEXT_AUDIT_DATE',
#                'nullable': True,
#                'references': None,
#                'size': None,
#                'type': 'DATE',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates if the asset is physical'",
#                'default': None,
#                'name': 'ASSET_PHYSICAL',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Indicates if the asset is BYOD  ( Bring Your Own "
#                           "Device)'",
#                'default': None,
#                'name': 'ASSET_BYOD',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'CPU specification of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_CPU_7',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'RAM size of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_RAM_8',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Disk type of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_DISK_TYPE_9',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Disk size of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_DISK_SIZE_10',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Display size of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_DISPLAY_SIZE_11',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Resolution of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_RESOLUTION_13',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Monitor type of the asset'",
#                'default': None,
#                'name': 'SNIPEIT_MONITOR_TYPE_14',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False},
#               {'check': None,
#                'comment': "'Number of repairs done on the asset'",
#                'default': None,
#                'name': 'SNIPEIT_REPAIR_COUNT_15',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Counter for asset check-ins'",
#                'default': None,
#                'name': 'ASSET_CHECKIN_COUNTER',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Counter for asset check-outs'",
#                'default': None,
#                'name': 'ASSET_CHECKOUT_COUNTER',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Counter for asset requests'",
#                'default': None,
#                'name': 'ASSET_REQUESTS_COUNTER',
#                'nullable': True,
#                'references': None,
#                'size': (38, 0),
#                'type': 'NUMBER',
#                'unique': False},
#               {'check': None,
#                'comment': "'Additional notes or comments related to the asset'",
#                'default': None,
#                'name': 'ASSET_NOTES',
#                'nullable': True,
#                'references': None,
#                'size': 16777216,
#                'type': 'VARCHAR',
#                'unique': False}],
#   'index': [],
#   'partitioned_by': [],
#   'primary_key': [],
#   'replace': True,
#   'schema': 'INFRA_SCHEMA',
#   'table_name': 'INFRA_ASSET_DETAILS',
#   'table_properties': {'project': 'INFRA_DB'},
#   'tablespace': None}]

# %%
for table in parse_results:
    parsed_ddl_dict  = dict()
    parsed_ddl_dict["table_name"] = table.get("table_name")
    parsed_ddl_dict["primary_keys"] = table.get("primary_keys")
    parsed_ddl_dict["columns"] = list()
    for column in table.get("columns"):
        column_dict = {
            "Name": column.get("name"),
            "Type": column.get("type"),
            "Description": column.get("comment"),
            }
# Out:
#   Cell In[10], line 4
#     parsed_ddl_dict[]
#                     ^
# SyntaxError: invalid syntax
